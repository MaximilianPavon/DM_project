# %%
# %matplotlib inline

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

import time
import numpy as np

# %%
# for parallelisation
from joblib import Parallel, delayed

import multiprocessing as mp
from functools import partial

# %%
def compute_shortest_path_distances_parallel(graph):
    num_cores = multiprocessing.cpu_count()
    print(num_cores, 'cores used')

    shortest_paths = Parallel(n_jobs=num_cores, batch_size=10)(delayed(nx.single_source_shortest_path_length)(graph, n) for n in graph)

    distances = []
    for _dict in shortest_paths:
        for key, value in _dict.items():
            distances.append(value)

    return distances

# %%
def compute_shortest_path_distances_parallel_mp(graph):
    num_cores = mp.cpu_count()
    print(num_cores, 'cores used')
    
    pool = mp.Pool(processes=num_cores)

    parallel_function = partial(nx.single_source_shortest_path_length, graph)
    sources = [source for source in graph]
    shortest_paths = pool.map(parallel_function, sources)

    pool.close()
    pool.join()

    distances = []
    for _dict in shortest_paths:
        for key, value in _dict.items():
            distances.append(value)

    return distances

# %%
# %%time

path_to_file = './data/wiki-Vote/wiki-Vote.txt'
G_dir = nx.read_edgelist(path_to_file, comments='#', delimiter='\t', nodetype=int, create_using=nx.DiGraph())
G_undir = nx.read_edgelist(path_to_file, comments='#', delimiter='\t', nodetype=int)
# Out:
# CPU times: user 718 ms, sys: 28.4 ms, total: 746 ms
# Wall time: 750 ms

# %%
# %%time
LSCC = max(nx.strongly_connected_component_subgraphs(G_dir), key=len)
# Out:
# CPU times: user 17.8 s, sys: 38.6 ms, total: 17.9 s
# Wall time: 18 s

# %%
# %%time
LWCC = max(nx.weakly_connected_component_subgraphs(G_dir), key=len)
LWCC = nx.to_undirected(LWCC)
# Out:
# CPU times: user 507 ms, sys: 16.3 ms, total: 523 ms
# Wall time: 531 ms

# %%
# %%time
print('LSCC edges: \t', LSCC.number_of_edges())
print('LSCC nodes: \t', LSCC.number_of_nodes())

print('LWCC edges: \t',LWCC.number_of_edges())
print('LWCC nodes: \t',LWCC.number_of_nodes())
# Out:
# LSCC edges: 	 39456
# LSCC nodes: 	 1300
# LWCC edges: 	 103663
# LWCC nodes: 	 7066
# CPU times: user 33.1 ms, sys: 2.86 ms, total: 35.9 ms
# Wall time: 42.6 ms

# %%
# %%time
length_arr = compute_shortest_path_distances_parallel_mp(LSCC)
# Out:
# 4 cores used
# CPU times: user 587 ms, sys: 115 ms, total: 702 ms
# Wall time: 9.29 s

# %%
# %%time
length_dir = dict(nx.all_pairs_shortest_path_length(LSCC))
# Out:
# CPU times: user 18 s, sys: 74.6 ms, total: 18.1 s
# Wall time: 18.2 s

# %%
# %%time
LSCC_nodes = LSCC.nodes()
dist_dir = []
for node_i in LSCC_nodes:
    for node_j in LSCC_nodes:
        if node_i != node_j:
            dist_dir.append(length_dir[node_i][node_j])
        
print('median distance:\t',np.percentile(dist_dir,50))
print('mean distance:\t',np.mean(dist_dir))
print('diameter:\t',np.max(dist_dir))
print('effective diameter:\t',np.percentile(dist_dir,90))
# Out:
# median distance:	 3.0
# mean distance:	 2.87928288032
# diameter:	 9
# effective diameter:	 4.0
# CPU times: user 847 ms, sys: 27.1 ms, total: 874 ms
# Wall time: 884 ms

# %%
# %%time
length_arr_LWCC = compute_shortest_path_distances_parallel_mp(LWCC)
# Out:
# 4 cores used
# CPU times: user 10.4 s, sys: 2.65 s, total: 13 s
# Wall time: 9min 28s

# %%
# %%time
length_undir = dict(nx.all_pairs_shortest_path_length(LWCC))
# Out:
# CPU times: user 19min 23s, sys: 5.68 s, total: 19min 29s
# Wall time: 19min 45s

# %%
# %%time
dist_undir = []
LWCC_nodes = LWCC.nodes()
for node_i in LWCC_nodes:
    for node_j in LWCC_nodes:
        if node_i != node_j:
            dist_undir.append(length_undir[node_i][node_j])
        
print('median distance:\t',np.percentile(dist_undir,50))
print('mean distance:\t',np.mean(dist_undir))
print('diameter:\t',np.max(dist_undir))
print('effective diameter:\t',np.percentile(dist_undir,90))
# Out:
# median distance:	 3.0
# mean distance:	 3.24750999023
# diameter:	 7
# effective diameter:	 4.0
# CPU times: user 22 s, sys: 1.21 s, total: 23.2 s
# Wall time: 23.6 s

# %% [markdown]
# # compute distance between two nodes for all nodes manually --> it is slower!

# %%
# %%time
start = time.time()
dist_dir = []
count = 0
LSCC_nodes = LSCC.nodes()
for i in LSCC_nodes:
    for j in LSCC_nodes:
        dist_dir.append(nx.shortest_path_length(LSCC,i,j))
        if(count%100000 == 0):
            print(np.round(count/10**6,1), 'mio \t', round(time.time() - start,1), '\t sec since start')
        count = count + 1
# Out:
# 0.0 mio 	 0.0 	 sec since start
# 0.1 mio 	 2.5 	 sec since start
# 0.2 mio 	 4.8 	 sec since start
# 0.3 mio 	 7.3 	 sec since start
# 0.4 mio 	 9.6 	 sec since start
# 0.5 mio 	 12.3 	 sec since start
# 0.6 mio 	 15.1 	 sec since start
# 0.7 mio 	 18.4 	 sec since start
# 0.8 mio 	 21.6 	 sec since start
# 0.9 mio 	 25.0 	 sec since start
# 1.0 mio 	 28.0 	 sec since start
# 1.1 mio 	 31.2 	 sec since start
# 1.2 mio 	 34.2 	 sec since start
# 1.3 mio 	 37.3 	 sec since start
# 1.4 mio 	 40.4 	 sec since start
# 1.5 mio 	 43.5 	 sec since start
# 1.6 mio 	 46.8 	 sec since start
# CPU times: user 48.3 s, sys: 396 ms, total: 48.7 s
# Wall time: 49.7 s

# %%
# %%time
start = time.time()
dist_undir = []
count = 0
for i in LWCC.nodes:
    for j in LWCC.nodes:
        if nx.has_path(LWCC,i,j):
            dist_dir.append(nx.shortest_path_length(LWCC,i,j))
        if(count%100000 == 0):
            print(round(time.time() - start,2), '\t seconds since start')
        count = count + 1
# Out:
# 0.0 	 seconds since start
# 8.17 	 seconds since start
# 16.33 	 seconds since start
# 23.44 	 seconds since start
# 29.93 	 seconds since start
# 37.67 	 seconds since start
# 45.08 	 seconds since start
# 50.09 	 seconds since start
# 56.74 	 seconds since start
# 63.71 	 seconds since start
# 69.71 	 seconds since start
# 78.03 	 seconds since start
# 84.88 	 seconds since start
# 91.66 	 seconds since start
# 98.13 	 seconds since start
# 103.83 	 seconds since start
# 110.07 	 seconds since start
# 115.99 	 seconds since start
# 121.29 	 seconds since start
# 127.02 	 seconds since start
# 131.91 	 seconds since start
# 138.6 	 seconds since start
# 143.82 	 seconds since start
# 150.12 	 seconds since start
# 157.49 	 seconds since start
# 164.05 	 seconds since start
# 171.01 	 seconds since start
# 176.73 	 seconds since start
# 182.64 	 seconds since start
# 190.41 	 seconds since start
# 195.73 	 seconds since start
# 202.43 	 seconds since start
# 207.81 	 seconds since start
# 213.27 	 seconds since start
# 218.23 	 seconds since start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# /anaconda/lib/python3.6/site-packages/networkx/algorithms/shortest_paths/generic.py in shortest_path_length(G, source, target, weight)
#     254             # Find shortest source-target path.
#     255             if weight is None:
# --> 256                 p = nx.bidirectional_shortest_path(G, source, target)
#     257                 paths = len(p)-1
#     258             else:
#
# /anaconda/lib/python3.6/site-packages/networkx/algorithms/shortest_paths/unweighted.py in bidirectional_shortest_path(G, source, target)
#     224
#     225     # call helper to do the real work
# --> 226     results = _bidirectional_pred_succ(G, source, target)
#     227     pred, succ, w = results
#     228
#
# /anaconda/lib/python3.6/site-packages/networkx/algorithms/shortest_paths/unweighted.py in _bidirectional_pred_succ(G, source, target)
#     278                     if w not in pred:
#     279                         forward_fringe.append(w)
# --> 280                         pred[w] = v
#     281                     if w in succ:  # path found
#     282                         return pred, succ, w
#
# KeyboardInterrupt:

# %%
# %%time
start = time.time()
dist_dir = []
count = 0
for i in G_dir.nodes:
    for j in G_dir.nodes:
        if nx.has_path(G_dir,i,j):
            dist_dir.append(nx.shortest_path_length(G_dir,i,j))
        if(count%100000 == 0):
            print(round(time.time() - start,2), '\t seconds since start')
        count = count + 1
# Out:
# 0.0 	 seconds since start
# 3.52 	 seconds since start
# 5.41 	 seconds since start
# 9.43 	 seconds since start
# 12.55 	 seconds since start
# 14.87 	 seconds since start
# 17.53 	 seconds since start
# 19.41 	 seconds since start
# 21.79 	 seconds since start
# 24.49 	 seconds since start
# 26.72 	 seconds since start
# 28.43 	 seconds since start
# 30.45 	 seconds since start
# 32.05 	 seconds since start
# 35.24 	 seconds since start
# 37.6 	 seconds since start
# 39.11 	 seconds since start
# 41.72 	 seconds since start
# 43.99 	 seconds since start
# 46.4 	 seconds since start
# 48.14 	 seconds since start
# 50.28 	 seconds since start
# 51.91 	 seconds since start
# 53.16 	 seconds since start
# 56.11 	 seconds since start
# 58.21 	 seconds since start
# 60.35 	 seconds since start
# 62.63 	 seconds since start
# 64.26 	 seconds since start
# 66.03 	 seconds since start
# 69.49 	 seconds since start
# 72.7 	 seconds since start
# 75.03 	 seconds since start
# 76.99 	 seconds since start
# 79.63 	 seconds since start
# 82.95 	 seconds since start
# 85.79 	 seconds since start
# 89.14 	 seconds since start
# 91.23 	 seconds since start
# 95.22 	 seconds since start
# 97.2 	 seconds since start
# 99.87 	 seconds since start
# 101.86 	 seconds since start
# 103.5 	 seconds since start
# 105.26 	 seconds since start
# 106.91 	 seconds since start
# 109.19 	 seconds since start
# 111.73 	 seconds since start
# 113.28 	 seconds since start
# 115.14 	 seconds since start
# 118.7 	 seconds since start
# 120.85 	 seconds since start
# 122.72 	 seconds since start
# 125.73 	 seconds since start
# 128.51 	 seconds since start
# 131.76 	 seconds since start
# 135.13 	 seconds since start
# 138.05 	 seconds since start
# 139.42 	 seconds since start
# 141.76 	 seconds since start
# 144.1 	 seconds since start
# 146.1 	 seconds since start
# 147.79 	 seconds since start
# 149.58 	 seconds since start
# 152.04 	 seconds since start
# 154.42 	 seconds since start
# 157.75 	 seconds since start
# 160.21 	 seconds since start
# 163.18 	 seconds since start
# 166.99 	 seconds since start
# 170.51 	 seconds since start
# 174.3 	 seconds since start
# 175.79 	 seconds since start
# 178.74 	 seconds since start
# 181.46 	 seconds since start
# 183.42 	 seconds since start
# 186.44 	 seconds since start
# 190.11 	 seconds since start
# 192.07 	 seconds since start
# 194.55 	 seconds since start
# 197.08 	 seconds since start
# 199.78 	 seconds since start
# 202.79 	 seconds since start
# 205.76 	 seconds since start
# 208.25 	 seconds since start
# 210.44 	 seconds since start
# 213.56 	 seconds since start
# 217.12 	 seconds since start
# 219.92 	 seconds since start
# 222.99 	 seconds since start
# 226.19 	 seconds since start
# 228.95 	 seconds since start
# 232.13 	 seconds since start
# 234.16 	 seconds since start
# 235.62 	 seconds since start
# 239.21 	 seconds since start
# 242.31 	 seconds since start
# 245.84 	 seconds since start
# 249.22 	 seconds since start
# 251.83 	 seconds since start
# 254.84 	 seconds since start
# 257.74 	 seconds since start
# 260.68 	 seconds since start
# 262.08 	 seconds since start
# 265.17 	 seconds since start
# 268.44 	 seconds since start
# 271.11 	 seconds since start
# 272.83 	 seconds since start
# 275.66 	 seconds since start
# 277.48 	 seconds since start
# 280.71 	 seconds since start
# 282.74 	 seconds since start
# 284.38 	 seconds since start
# 286.89 	 seconds since start
# 288.86 	 seconds since start
# 291.65 	 seconds since start
# 293.41 	 seconds since start
# 296.22 	 seconds since start
# 298.79 	 seconds since start
# 301.02 	 seconds since start
# 303.7 	 seconds since start
# 306.82 	 seconds since start
# 309.59 	 seconds since start
# 311.56 	 seconds since start
# 313.82 	 seconds since start
# 316.9 	 seconds since start
# 320.06 	 seconds since start
# 322.53 	 seconds since start
# 325.09 	 seconds since start
# 327.95 	 seconds since start
# 330.74 	 seconds since start
# 333.67 	 seconds since start
# 336.55 	 seconds since start
# 338.7 	 seconds since start
# 341.38 	 seconds since start
# 343.31 	 seconds since start
# 345.5 	 seconds since start
# 347.8 	 seconds since start
# 350.22 	 seconds since start
# 352.18 	 seconds since start
# 354.12 	 seconds since start
# 357.11 	 seconds since start
# 360.32 	 seconds since start
# 363.15 	 seconds since start
# 366.19 	 seconds since start
# 368.42 	 seconds since start
# 370.54 	 seconds since start
# 372.05 	 seconds since start
# 374.71 	 seconds since start
# 376.54 	 seconds since start
# 378.07 	 seconds since start
# 379.97 	 seconds since start
# 381.95 	 seconds since start
# 383.74 	 seconds since start
# 385.72 	 seconds since start
# 388.16 	 seconds since start
# 391.37 	 seconds since start
# 394.61 	 seconds since start
# 396.97 	 seconds since start
# 399.45 	 seconds since start
# 401.66 	 seconds since start
# 403.51 	 seconds since start
# 405.7 	 seconds since start
# 407.8 	 seconds since start
# 409.22 	 seconds since start
# 411.94 	 seconds since start
# 415.0 	 seconds since start
# 417.07 	 seconds since start
# 419.0 	 seconds since start
# 421.6 	 seconds since start
# 424.47 	 seconds since start
# 426.19 	 seconds since start
# 429.38 	 seconds since start
# 431.98 	 seconds since start
# 433.85 	 seconds since start
# 434.44 	 seconds since start
# 436.59 	 seconds since start
# 438.12 	 seconds since start
# 440.15 	 seconds since start
# 442.8 	 seconds since start
# 446.16 	 seconds since start
# 449.08 	 seconds since start
# 451.45 	 seconds since start
# 454.43 	 seconds since start
# 457.16 	 seconds since start
# 460.43 	 seconds since start
# 463.75 	 seconds since start
# 466.05 	 seconds since start
# 468.25 	 seconds since start
# 470.94 	 seconds since start
# 473.28 	 seconds since start
# 474.67 	 seconds since start
# 477.18 	 seconds since start
# 478.85 	 seconds since start
# 480.93 	 seconds since start
# 483.87 	 seconds since start
# 487.87 	 seconds since start
# 492.9 	 seconds since start
# 495.35 	 seconds since start
# 498.3 	 seconds since start
# 500.9 	 seconds since start
# 503.64 	 seconds since start
# 506.89 	 seconds since start
# 509.78 	 seconds since start
# 511.88 	 seconds since start
# 514.37 	 seconds since start
# 517.57 	 seconds since start
# 519.67 	 seconds since start
# 522.52 	 seconds since start
# 525.74 	 seconds since start
# 527.86 	 seconds since start
# 529.92 	 seconds since start
# 532.01 	 seconds since start
# 534.26 	 seconds since start
# 537.14 	 seconds since start
# 539.47 	 seconds since start
# 542.16 	 seconds since start
# 544.69 	 seconds since start
# 547.42 	 seconds since start
# 550.1 	 seconds since start
# 552.61 	 seconds since start
# 554.71 	 seconds since start
# 557.47 	 seconds since start
# 559.35 	 seconds since start
# 561.58 	 seconds since start
# 564.61 	 seconds since start
# 567.3 	 seconds since start
# 570.21 	 seconds since start
# 573.35 	 seconds since start
# 575.96 	 seconds since start
# 577.92 	 seconds since start
# 581.7 	 seconds since start
# 584.62 	 seconds since start
# 587.52 	 seconds since start
# 590.55 	 seconds since start
# 593.3 	 seconds since start
# 595.62 	 seconds since start
# 598.84 	 seconds since start
# 600.98 	 seconds since start
# 603.76 	 seconds since start
# 606.58 	 seconds since start
# 609.31 	 seconds since start
# 612.37 	 seconds since start
# 614.14 	 seconds since start
# 617.19 	 seconds since start
# 620.0 	 seconds since start
# 622.93 	 seconds since start
# 625.26 	 seconds since start
# 626.6 	 seconds since start
# 629.39 	 seconds since start
# 631.06 	 seconds since start
# 633.28 	 seconds since start
# 634.29 	 seconds since start
# 635.49 	 seconds since start
# 638.1 	 seconds since start
# 640.37 	 seconds since start
# 642.33 	 seconds since start
# 645.32 	 seconds since start
# 648.11 	 seconds since start
# 649.34 	 seconds since start
# 651.5 	 seconds since start
# 653.06 	 seconds since start
# 654.32 	 seconds since start
# 655.77 	 seconds since start
# 658.23 	 seconds since start
# 661.05 	 seconds since start
# 663.7 	 seconds since start
# 666.82 	 seconds since start
# 669.18 	 seconds since start
# 672.12 	 seconds since start
# 673.84 	 seconds since start
# 675.44 	 seconds since start
# 677.32 	 seconds since start
# 679.97 	 seconds since start
# 681.47 	 seconds since start
# 683.7 	 seconds since start
# 686.12 	 seconds since start
# 688.37 	 seconds since start
# 692.22 	 seconds since start
# 695.18 	 seconds since start
# 696.87 	 seconds since start
# 700.61 	 seconds since start
# 703.77 	 seconds since start
# 706.27 	 seconds since start
# 708.35 	 seconds since start
# 710.65 	 seconds since start
# 712.6 	 seconds since start
# 715.19 	 seconds since start
# 718.43 	 seconds since start
# 720.63 	 seconds since start
# 725.86 	 seconds since start
# 728.93 	 seconds since start
# 730.84 	 seconds since start
# 732.58 	 seconds since start
# 734.07 	 seconds since start
# 738.11 	 seconds since start
# 740.8 	 seconds since start
# 744.83 	 seconds since start
# 748.17 	 seconds since start
# 750.48 	 seconds since start
# 752.03 	 seconds since start
# 754.65 	 seconds since start
# 757.35 	 seconds since start
# 760.15 	 seconds since start
# 762.24 	 seconds since start
# 764.84 	 seconds since start
# 767.67 	 seconds since start
# 770.05 	 seconds since start
# 772.27 	 seconds since start
# 775.91 	 seconds since start
# 778.41 	 seconds since start
# 780.94 	 seconds since start
# 784.45 	 seconds since start
# 787.45 	 seconds since start
# 790.87 	 seconds since start
# 793.67 	 seconds since start
# 796.99 	 seconds since start
# 800.21 	 seconds since start
# 802.68 	 seconds since start
# 805.12 	 seconds since start
# 807.92 	 seconds since start
# 810.49 	 seconds since start
# 813.01 	 seconds since start
# 815.59 	 seconds since start
# 817.87 	 seconds since start
# 820.05 	 seconds since start
# 822.48 	 seconds since start
# 825.1 	 seconds since start
# 827.74 	 seconds since start
# 830.03 	 seconds since start
# 832.85 	 seconds since start
# 836.01 	 seconds since start
# 838.97 	 seconds since start
# 842.74 	 seconds since start
# 846.62 	 seconds since start
# 848.82 	 seconds since start
# 851.58 	 seconds since start
# 854.29 	 seconds since start
# 856.0 	 seconds since start
# 859.01 	 seconds since start
# 861.49 	 seconds since start
# 864.68 	 seconds since start
# 868.56 	 seconds since start
# 870.54 	 seconds since start
# 872.46 	 seconds since start
# 874.44 	 seconds since start
# 877.79 	 seconds since start
# 880.76 	 seconds since start
# 883.51 	 seconds since start
# 885.23 	 seconds since start
# 888.1 	 seconds since start
# 890.1 	 seconds since start
# 892.94 	 seconds since start
# 895.72 	 seconds since start
# 897.93 	 seconds since start
# 900.47 	 seconds since start
# 903.69 	 seconds since start
# 907.35 	 seconds since start
# 911.12 	 seconds since start
# 913.76 	 seconds since start
# 916.13 	 seconds since start
# 920.05 	 seconds since start
# 923.16 	 seconds since start
# 925.7 	 seconds since start
# 929.75 	 seconds since start
# 933.4 	 seconds since start
# 935.3 	 seconds since start
# 938.03 	 seconds since start
# 940.68 	 seconds since start
# 943.45 	 seconds since start
# 946.37 	 seconds since start
# 949.44 	 seconds since start
# 952.63 	 seconds since start
# 956.32 	 seconds since start
# 958.87 	 seconds since start
# 960.9 	 seconds since start
# 962.84 	 seconds since start
# 966.21 	 seconds since start
# 968.49 	 seconds since start
# 971.59 	 seconds since start
# 975.21 	 seconds since start
# 978.09 	 seconds since start
# 980.47 	 seconds since start
# 1313.36 	 seconds since start
# 1316.2 	 seconds since start
# 1319.69 	 seconds since start
# 1323.96 	 seconds since start
# 1335.43 	 seconds since start
# 1338.26 	 seconds since start
# 1341.85 	 seconds since start
# 1345.71 	 seconds since start
# 1349.41 	 seconds since start
# 1352.92 	 seconds since start
# 1356.54 	 seconds since start
# 1360.68 	 seconds since start
# 1365.15 	 seconds since start
# 1369.5 	 seconds since start
# 1372.7 	 seconds since start
# 1376.61 	 seconds since start
# 1379.9 	 seconds since start
# 2628.72 	 seconds since start
# 2631.77 	 seconds since start
# 2634.46 	 seconds since start
# 2638.97 	 seconds since start
# 2649.42 	 seconds since start
# 2652.72 	 seconds since start
# 2655.09 	 seconds since start
# 2659.7 	 seconds since start
# 2665.23 	 seconds since start
# 2670.07 	 seconds since start
# 2673.89 	 seconds since start
# 2676.93 	 seconds since start
# 2742.47 	 seconds since start
# 2745.2 	 seconds since start
# 2747.74 	 seconds since start
# 2760.43 	 seconds since start
# 2764.93 	 seconds since start
# 2768.41 	 seconds since start
# 2771.0 	 seconds since start
# 2795.85 	 seconds since start
# 2799.27 	 seconds since start
# 2802.64 	 seconds since start
# 2805.69 	 seconds since start
# 2809.47 	 seconds since start
# 2811.9 	 seconds since start
# 2814.01 	 seconds since start
# 2816.75 	 seconds since start
# 2820.13 	 seconds since start
# 2823.9 	 seconds since start
# 2825.4 	 seconds since start
# 2828.23 	 seconds since start
# 2831.98 	 seconds since start
# 2835.36 	 seconds since start
# 2838.19 	 seconds since start
# 2841.93 	 seconds since start
# 2845.14 	 seconds since start
# 2848.55 	 seconds since start
# 2851.34 	 seconds since start
# 2853.98 	 seconds since start
# 2857.88 	 seconds since start
# 2861.6 	 seconds since start
# 2864.66 	 seconds since start
# 2866.21 	 seconds since start
# 2869.28 	 seconds since start
# 2871.65 	 seconds since start
# 2875.01 	 seconds since start
# 2878.27 	 seconds since start
# 2882.0 	 seconds since start
# 2885.0 	 seconds since start
# 2888.86 	 seconds since start
# 2891.99 	 seconds since start
# 2895.86 	 seconds since start
# 2898.45 	 seconds since start
# 2901.69 	 seconds since start
# 2905.5 	 seconds since start
# 2909.69 	 seconds since start
# 2912.46 	 seconds since start
# 2917.42 	 seconds since start
# 2921.71 	 seconds since start
# 2923.97 	 seconds since start
# 2926.83 	 seconds since start
# 2930.77 	 seconds since start
# 2934.56 	 seconds since start
# 2936.78 	 seconds since start
# 2940.25 	 seconds since start
# 2945.13 	 seconds since start
# 2948.86 	 seconds since start
# 2952.1 	 seconds since start
# 2956.15 	 seconds since start
# 2959.49 	 seconds since start
# 2962.75 	 seconds since start
# 2966.52 	 seconds since start
# 2969.01 	 seconds since start
# 2971.82 	 seconds since start
# 2973.24 	 seconds since start
# 2976.62 	 seconds since start
# 2980.65 	 seconds since start
# 2983.53 	 seconds since start
# 2986.06 	 seconds since start
# 2990.65 	 seconds since start
# 2992.98 	 seconds since start
# 2996.47 	 seconds since start
# 2999.65 	 seconds since start
# 3002.94 	 seconds since start
# 3005.37 	 seconds since start
# 3008.06 	 seconds since start
# 3010.78 	 seconds since start
# 3015.23 	 seconds since start
# 3020.03 	 seconds since start
# 3022.53 	 seconds since start
# 3025.67 	 seconds since start
# 3028.66 	 seconds since start
# 3031.68 	 seconds since start
# 3034.8 	 seconds since start
# 3037.5 	 seconds since start
# 3039.77 	 seconds since start
# 3043.56 	 seconds since start
# 3046.44 	 seconds since start
# 3049.08 	 seconds since start
# 3052.52 	 seconds since start
# 3054.8 	 seconds since start
# 3056.41 	 seconds since start
# 3059.0 	 seconds since start
# 3060.78 	 seconds since start
# 3063.96 	 seconds since start
# 3066.92 	 seconds since start
# 3070.96 	 seconds since start
# CPU times: user 23min 19s, sys: 5.44 s, total: 23min 25s
# Wall time: 51min 11s

# %%
print('median distance: ',np.percentile(dist_dir,50))
print('mean distance: ',np.mean(dist_dir))
print('diameter: ',np.max(dist_dir))
print('effective diameter: ',np.percentile(dist_dir,90))
# Out:
# median distance:  3.0
# mean distance:  3.33902266947
# diameter:  10
# effective diameter:  4.0

# %%
nx.shortest_path_length(LWCC,30,)
# Out:
# 0
